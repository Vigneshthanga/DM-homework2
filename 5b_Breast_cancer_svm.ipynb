# %%
from sklearn.svm import SVC
from sklearn import datasets
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn import metrics
from inspect import signature

dframe = pd.read_csv("/Users/vigneshkumarthangarajan/Documents/255-Data-Mining/homework-2/data2/breast_cancer.csv")

dframe['Class'] = dframe['Class'].map({'malignant': 1, 'benign': 0})

labels = dframe.Class
feature_set = dframe.drop('Class', axis=1)
feature_set = feature_set.drop('Id', axis=1)

scaler = StandardScaler()
X_std = scaler.fit_transform(feature_set)

X_train, X_test, y_train, y_test = train_test_split(feature_set, labels, test_size=0.3, random_state=1)


clf = SVC(gamma='auto')
clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)

print(metrics.accuracy_score(y_test, y_pred))

print(metrics.confusion_matrix(y_test, y_pred))
tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred).ravel()
print("True Negative: "+str(tn) + " False Positive: "+ str(fp) +" False Negative: " + str(fn) + " True Positive: " + str(tp))

print(feature_set.dtypes)

print("Indices of support vector: ")
print(clf.support_)

sv = clf.support_vectors_ 
print("Following are support vectors: ")
print(sv)

print("Number of support vectors in class Malignant and Benigh respectively are: ")
print(clf.n_support_)
# Out:
# 0.9707317073170731
# [[127   6]
#  [  0  72]]
# True Negative: 127 False Positive: 6 False Negative: 0 True Positive: 72
# Cl.thickness       int64
# Cell.size          int64
# Cell.shape         int64
# Marg.adhesion      int64
# Epith.c.size       int64
# Bare.nuclei        int64
# Bl.cromatin        int64
# Normal.nucleoli    int64
# Mitoses            int64
# dtype: object
# Indices of support vector:
# [ 11  26  32  43  45  53  59  62  66  97  99 106 109 111 127 131 136 140
#  158 159 168 169 170 179 196 209 210 212 213 235 248 254 267 269 282 286
#  294 301 322 359 364 369 370 374 379 391 400 425 426 427 469 473   1   3
#    4   5   9  10  14  15  18  19  22  23  28  30  31  37  38  46  55  57
#   61  63  64  68  71  77  81  82  84  86  87  89  90  91  95 102 103 108
#  112 114 115 116 117 118 121 122 128 132 133 135 139 141 142 143 144 147
#  154 161 162 167 176 177 183 188 190 191 192 193 198 201 203 204 205 211
# ...
