# %%
import numpy as np
import numpy.random as random
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def Normalplot(marks):
    marks1.sort()
    norm=random.normal(0,2,len(marks1))
    norm.sort()
    plt.figure(figsize=(12,8),facecolor='1.0') 

    plt.plot(norm,marks1,"o")

    z = np.polyfit(norm,marks1, 1)
    p = np.poly1d(z)
    plt.plot(norm,p(norm),"k--", linewidth=2)
    plt.title("Normal Q-Q plot", size=28)
    plt.xlabel("Theoretical quantiles", size=24)
    plt.ylabel("Expreimental quantiles", size=24)
    plt.tick_params(labelsize=16)
    plt.show()

marks1= [47, 63, 71, 39, 47, 49, 43, 37, 81, 69, 38, 13, 29, 61, 49, 53, 57, 23, 58, 17, 73, 33, 29]
marks2 = [20, 49, 85, 17, 33, 62, 93, 64, 37, 81, 22, 18, 45, 42, 14, 39, 67, 47, 53, 73, 58, 84, 21]
Normalplot(marks1)
Normalplot(marks2)
